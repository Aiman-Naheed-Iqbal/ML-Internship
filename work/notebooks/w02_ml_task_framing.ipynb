# %% [markdown]
# <a href="https://colab.research.google.com/github/Aiman-Naheed-Iqbal/ML-Internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Aiman-Naheed-Iqbal/ML-Internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %%
#Classification, because we need to decide whether to intervene on a high-risk account or not.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
#Target: What exact column/event are you predicting?

#Label Source:

#Observed outcome: Actual historic events (e.g., customer churned, transaction flagged as fraud by chargeback).

#Defined rule / Proxy: A created proxy label when the true label isn't directly recorded (e.g., "inactive for 90 days" as a proxy for churn).

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
3. #Success Metric & Target ThresholdMetric:
#Pick one primary metric (e.g., Precision@K, Recall, ROC-AUC, PR-AUC, or MAE).
#Baseline & Target: Define your benchmark
 #(e.g., "Current rule-based baseline achieves 0.62 Recall; our target for 'good' is $\ge 0.75$ Recall at a fixed 90% Precision.").
# Out:
# 3.0

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
import pandas as pd

# Define data manually in Python
data = {
    'customer_id': [101, 102, 103, 104, 105],
    'monthly_spend': [120.50, 45.00, 310.20, 89.99, 15.00],
    'days_since_last_login': [2, 45, 1, 12, 90],
    'churned': [0, 1, 0, 0, 1]  # 1 = Yes, 0 = No
}

# Convert dictionary into a DataFrame
df = pd.DataFrame(data)

# Print unit of analysis details
print("Unit of Analysis: One row per customer")
print(f"Dataset shape: {df.shape[0]} rows, {df.shape[1]} columns")

# Display the table
display(df.head(3))
# Out:
# Unit of Analysis: One row per customer
# Dataset shape: 5 rows, 4 columns
#    customer_id  monthly_spend  days_since_last_login  churned
# 0          101          120.5                      2        0
# 1          102           45.0                     45        1
# 2          103          310.2                      1        0

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
#Complexity: Explain feature interactions, non-linear dependencies, or high dimensionality that make static if-else rules fragile or hard to maintain.

#Adaptability: Mention how pattern drift or evolving data makes hardcoded thresholds stale over time.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
